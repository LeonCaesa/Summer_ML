# %%
from ML2020 import *
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ###  1. Data Cleaning

# %%
raw_data = pd.read_csv("data/constituents_2013_fund_tech.csv")

# %%
raw_data.head()
# Out:
#    Unnamed: 0   permno  gvkey   fyear   sic2  spi        mve_f        bm  \
# 0           0  79411.0  28648  2012.0  b'59'  NaN   6889.63530  0.163084
# 1           1  11081.0  14489  2012.0  b'35'  NaN  23011.12000  0.464123
# 2           2  16678.0   6502  2012.0  b'54'  NaN  14237.80000  0.295481
# 3           3  18403.0   8446  2012.0  b'53'  NaN   4458.36900  0.711247
# 4           4  40539.0  11672  2012.0  b'56'  NaN  32705.89236  0.112088
#
#          ep     cashpr    ...     TRIMA  TRIX   TYPPRICE  ULTOSC       Volume  \
# 0  0.056538  11.502685    ...       NaN   NaN        NaN     NaN          NaN
# 1  0.103081  -1.509500    ...       NaN   NaN        NaN     NaN          NaN
# 2  0.105143  -3.578541    ...       NaN   NaN  21.068333     NaN  132791600.0
# 3 -0.220933  -2.544765    ...       NaN   NaN        NaN     NaN          NaN
# 4  0.058298  11.704499    ...       NaN   NaN  29.405000     NaN  126245200.0
#
#    WCLPRICE  WILLR  WMA  lagClose       ret
# 0       NaN    NaN  NaN       NaN       NaN
# 1       NaN    NaN  NaN       NaN       NaN
# 2  21.15625    NaN  NaN    20.170  0.061973
# 3       NaN    NaN  NaN       NaN       NaN
# 4  29.65250    NaN  NaN    28.195  0.078028
#
# [5 rows x 310 columns]

# %%
ML_object = MLEngineer(raw_data, num_stocks=40,
                       trading_window = 12, algorithm='SVM', small_sample = False, method='median')
ML_object.data_processing()
# Out:
# date format corrected
# missing indicator variables deleted
# continous variables containing infinity deleted
# missing continuous variables filled in with median

# %%
ML_object.clean_data.head()
# Out:
#    Unnamed: 0  gvkey   permno   fyear       spi        mve_f        bm  \
# 0           0  28648  79411.0  2012.0 -0.002863   6889.63530  0.163084
# 1           1  14489  11081.0  2012.0 -0.002863  23011.12000  0.464123
# 2           2   6502  16678.0  2012.0 -0.002863  14237.80000  0.295481
# 3           3   8446  18403.0  2012.0 -0.002863   4458.36900  0.711247
# 4           4  11672  40539.0  2012.0 -0.002863  32705.89236  0.112088
#
#          ep     cashpr        dy   ...       TRIMA   TYPPRICE     ULTOSC  \
# 0  0.056538  11.502685  0.009955   ...    60.24725  61.469999  55.736725
# 1  0.103081  -1.509500  0.012081   ...    60.24725  61.469999  55.736725
# 2  0.105143  -3.578541  0.019736   ...    60.24725  21.068333  55.736725
# 3 -0.220933  -2.544765  0.010542   ...    60.24725  61.469999  55.736725
# 4  0.058298  11.704499  0.010280   ...    60.24725  29.405000  55.736725
#
#         Volume  WCLPRICE     WILLR        WMA   lagClose       ret    DATE
# 0   55489800.0  61.56250 -35.50184  61.692925  61.560001  0.006817 2013-09
# 1   55489800.0  61.56250 -35.50184  61.692925  61.560001  0.006817 2013-10
# 2  132791600.0  21.15625 -35.50184  61.692925  20.170000  0.061973 2013-10
# 3   55489800.0  61.56250 -35.50184  61.692925  61.560001  0.006817 2013-10
# 4  126245200.0  29.65250 -35.50184  61.692925  28.195000  0.078028 2013-10
#
# [5 rows x 303 columns]

# %% [markdown]
# ###  2. Return Prediction

# %%
time_list =['2014-10-01', '2018-11-01']
returns_long = ML_object.profit_construct(time_list, strategy ='long_equal_weighted')
# Out:
# 2014-10
# 2014-11
# 2014-12
# 2015-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-565a13fce864> in <module>()
#       1 time_list =['2014-10-01', '2018-11-01']
# ----> 2 returns_long = ML_object.profit_construct(time_list, strategy ='long_equal_weighted')
#
# /projectnb2/powermc/robustvb/2020_Summer_ML/Summer_ML/ML2020.py in profit_construct(self, time_list, strategy)
#     124         while time_step != time_end:
#     125             print(time_step)
# --> 126             port_id, indx_rank = self.opti_stocks(time_step)
#     127
#     128             if strategy == 'long_equal_weighted':
#
# /projectnb2/powermc/robustvb/2020_Summer_ML/Summer_ML/ML2020.py in opti_stocks(self, time_step)
#      94             Method to output optimally selected stocks
#      95         """
# ---> 96         y_hat, y_test = self.return_prediction(time_step)
#      97
#      98         indx_rank = np.argsort(y_hat)
#
# /projectnb2/powermc/robustvb/2020_Summer_ML/Summer_ML/ML2020.py in return_prediction(self, time_step)
#      54
#      55         self.x_train, self.y_train, self.x_test, self.y_test = self.split_date(
# ---> 56             time_step)
#      57
#      58         model = self.model(self.x_train, self.y_train,
#
# /projectnb2/powermc/robustvb/2020_Summer_ML/Summer_ML/ML2020.py in split_date(self, time_step)
#      76         dataset = self.clean_data
#      77
# ---> 78         train = dataset.loc[(dataset['DATE'] > time_train_start)
#      79                             & (dataset['DATE'] <= time)]
#      80         test = dataset.loc[dataset['DATE'] == time_test_end]
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# pandas/_libs/tslibs/period.pyx in pandas._libs.tslibs.period._Period.__richcmp__()
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/tseries/offsets.py in __ne__(self, other)
#     335
#     336     def __ne__(self, other):
# --> 337         return not self == other
#     338
#     339     def __hash__(self):
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/tseries/offsets.py in __eq__(self, other)
#     332             return False
#     333
# --> 334         return self._params() == other._params()
#     335
#     336     def __ne__(self, other):
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/tseries/offsets.py in _params(self)
#     292             all_paras.pop('holidays')
#     293         exclude = ['kwds', 'name', 'normalize', 'calendar']
# --> 294         attrs = [(k, v) for k, v in all_paras.items()
#     295                  if (k not in exclude) and (k[0] != '_')]
#     296         attrs = sorted(set(attrs))
#
# /share/pkg.7/python3/3.6.5/install/lib/python3.6/site-packages/pandas/tseries/offsets.py in <listcomp>(.0)
#     293         exclude = ['kwds', 'name', 'normalize', 'calendar']
#     294         attrs = [(k, v) for k, v in all_paras.items()
# --> 295                  if (k not in exclude) and (k[0] != '_')]
#     296         attrs = sorted(set(attrs))
#     297         params = tuple([str(self.__class__)] + attrs)
#
# KeyboardInterrupt:

# %%
returns_short = - np.array(ML_object.profit_construct(time_list, strategy ='short_equal_weighted'))

# %% [markdown]
# ### 3. Return Plot

# %%
ML_object.return_plot(returns_long)

# %%
ML_object.return_plot(returns_short)
